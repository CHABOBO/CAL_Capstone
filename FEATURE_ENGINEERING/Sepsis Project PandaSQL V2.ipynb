# %%
# !pip install -U pandasql

# %%
#The main function used in pandasql is sqldf. sqldf accepts 2 parameters 
# - a sql query string 
# - a set of session/environment variables (locals() or globals())

# Specifying locals() or globals() can get tedious. You can define a short helper function to fix this...

from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
import pandas
import pandasql

filename = 'C:\BerkeleyMIDSProgram\W210. Capstone\condensed_sepsis.csv'
sepsis_data = pandas.read_csv(filename)
print sepsis_data.columns
# Out:
# Index([u'Unnamed: 0', u'patient_id', u'encounter_id', u'time', u'loc_cat',
#        u'IVF_meds', u'IVF_volume', u'IV_intake', u'fio2', u'fio2_vent',
#        ...
#        u'hb_c', u'o2sat_c', u'platelet_count_c', u'ppi_c', u'rr_c', u'sbp_c',
#        u'sgot_c', u'sodium_c', u'wbcecart', u'wbc_c'],
#       dtype='object', length=278)

# %%
print sepsis_data.head()
# Out:
#    Unnamed: 0  patient_id  encounter_id                time loc_cat  IVF_meds  \
# 0          65     1437648       1867781  14mar2009 21:00:00    WARD       NaN
# 1          66     1437648       1867781  15mar2009 12:17:00    WARD       NaN
# 2          67     1437648       1867781  15mar2009 05:04:00    WARD       NaN
# 3          68     1437648       1867781  12mar2009 22:07:00    WARD       NaN
# 4          69     1437648       1867781  16mar2009 10:00:00    WARD       NaN
#
#    IVF_volume  IV_intake  fio2  fio2_vent  ...    hb_c  o2sat_c  \
# 0         NaN        NaN   NaN        NaN  ...    14.3     96.0
# 1         NaN        NaN   NaN        NaN  ...    14.4     99.0
# 2         NaN        NaN   NaN        NaN  ...    14.4     96.0
# 3         NaN        NaN   NaN        NaN  ...    15.0     99.0
# 4         NaN        NaN   NaN        NaN  ...    13.7     99.0
#
#    platelet_count_c     ppi_c  rr_c  sbp_c  sgot_c  sodium_c  wbcecart  wbc_c
# ...

# %%
for column in sepsis_data:
    if column in ['IVF_meds', 			'fio2', 	'fio2_vent', 	'gastric_output', 	'gcs_eye', 	'gcs_motor', 	'gcs_score', 	'gcs_verbal', 'map_notcalc', 	'map_zzz', 		'ni_fio2', 			'o2_flow', 	'rass', 		'temp', 	'tube_output', 	'wound_output', 	'fio2_final', 	'fio2_final2', 	'sf_ratio_old', 			'abs_bands', 	'abs_neutrophils', 	'alt', 	'antitrypsin', 		'bands', 	'basophils', 	'blasts', 		'chloride', 	'cortisol','eosinophils', 	'esr', 	'hb1198', 	'hb1200', 		'hc03_ven', 	'hco3_art', 	'hematocrit', 	'inr', 	'ketones', 		'lactate_wholebld1434', 		'lactic_acid', 	'lipase', 	'lymphocytes', 	'magnesium', 	'mcv', 	'metamyelocytes', 	'monocytes', 	'neutrophils', 	'nrbc', 	'osmolality', 	'paco2', 	'pao2', 			'ph1250', 	'ph1819', 	'ph272', 			'phosphate', 	'potassium', 	'promyelocytes', 	'total_protein', 	'ptt', 	'pvco2', 	'pvo2', 	'rbc', 	'rdw', 	'svo2_2641', 		'troponin_old', 	'lactate', 			'bmi', 'drip_dexmedetomidine', 	'drip_dobutamine', 	'drip_dopamine', 	'drip_fentanyl', 	'drip_midazolam', 	'drip_milrinone', 	'drip_morphine', 	'drip_norepinephrine', 	'drip_phenylephrine', 	'drip_propofol', 	'drip_vasopressin', 	'pain_scale', 			'braden_activity', 	'braden_friction', 	'braden_mobility', 	'braden_moisture', 	'braden_nutrition', 	'braden_scale', 	'braden_sensory', 	'morse_ambaid', 		'morse_fallhistory', 	'morse_gaittransfer', 	'morse_ivdevice', 	'morse_mentalstatus', 	'morse_score', 	'morse_secdiag', 				'rosc', 					'troponin', 	'troponin_bin', 										'fio2_finaltest', 	'fio2_final3', 	'sf_ratio', 'los', 											'los_total', 	'temp_c', 		'num_icustays', 	'temp_c_ecart', 	'potassium_ecart', 	'ecart_score', 	'pao2_sofa', 	'fio2_final3_sofa', 	'gcs_score_sofa', 'sofa_coag', 	'sofa_bili', 	'sofa_card', 	'sofa_gcs', 	'sofa_cr', 	'sofa_score', 	'encount_enum', 	'antibiotic_ad', 	'antiarrhythmic_ad', 	'anticoag_ad', 	'antipsych_ad', 	'avnodal_ad', 	'diuretic_ad', 	'fungal_ad', 	'hypogly_ad', 	'hpogly_ad', 	'immuno_ad', 	'steroid_ad', 	'antiviral_ad', 	'chest_xray', 	'chestab_w_ct', 	'chestab_wo_ct', 	'headneck_w_ct', 	'cul_blood_ord', 	'cul_urine_ord', 	'cul_other_ord', 	'cul_stool_ord', 	'elix_comorb', 	'urin_cath', 	'urin_output', 	'mech_ventil', 	'benzo_diaz', 		'ekg_ecg', 	'central_line', 	'mob_lo', 	'age_yr', 	'albumin_c', 	'allphos_c', 	'avpu_c', 	'bun_c', 	'bun_cr_c', 	'calcium_c', 	'co2_c', 	'creatinine_c', 	'dbp_c', 	'gluc_ser_c', 	'hb_c', 	'o2sat_c', 	'platelet_count_c', 	'ppi_c', 	'rr_c', 	'sbp_c', 	'sgot_c', 	'sodium_c','wbc_c']:
        print column 
        
        avg = sepsis_data[column].mean()
        stddev = sepsis_data[column].std()
        
        print avg
        print stddev 
                
        sepsis_data[column] = sepsis_data[column].transform(lambda x: (x - avg) / stddev)
# Out:
# IVF_meds
# 121.913031353
# 541.021062099
# fio2
# 54.0253071253
# 20.4653948323
# fio2_vent
# 55.4566611691
# 29.2040236965
# gastric_output
# 133.437934459
# 238.760575049
# gcs_eye
# 3.13990973565
# 1.12124343055
# gcs_motor
# 4.77443609023
# 1.67003934146
# gcs_score
# 11.0648610121
# 4.25297560076
# gcs_verbal
# 3.1910652921
# 1.78000584377
# map_notcalc
# 78.2415904573
# 21.5749496274
# map_zzz
# 86.0532124126
# 16.4072591179
# ni_fio2
# 57.5860215054
# 26.8325260122
# o2_flow
# 8.86978461538
# 17.4243148904
# rass
# -2.07836456559
# 1.54632652173
# temp
# 98.1005904613
# 1.78481752739
# tube_output
# 30.3553719008
# 92.975937004
# wound_output
# 180.9375
# 346.061784091
# fio2_final
# 35.7034194866
# 20.5249897259
# fio2_final2
# 35.7034194866
# 20.5249897259
# sf_ratio_old
# 3.26155744452
# 1.28298911264
# abs_bands
# 1.22291667732
# 2.00248188172
# abs_neutrophils
# 9.89695958597
# 8.06011572693
# alt
# 112.882804995
# 535.595898996
# antitrypsin
# 153.2
# 20.2163300329
# ...

# %%
print sepsis_data.head()
# Out:
#    Unnamed: 0  patient_id  encounter_id                time loc_cat  IVF_meds  \
# 0          65     1437648       1867781  14mar2009 21:00:00    WARD       NaN
# 1          66     1437648       1867781  15mar2009 12:17:00    WARD       NaN
# 2          67     1437648       1867781  15mar2009 05:04:00    WARD       NaN
# 3          68     1437648       1867781  12mar2009 22:07:00    WARD       NaN
# 4          69     1437648       1867781  16mar2009 10:00:00    WARD       NaN
#
#    IVF_volume  IV_intake  fio2  fio2_vent    ...         hb_c   o2sat_c  \
# 0         NaN        NaN   NaN        NaN    ...     2.472861 -0.395054
# 1         NaN        NaN   NaN        NaN    ...     2.532744  0.547547
# 2         NaN        NaN   NaN        NaN    ...     2.532744 -0.395054
# 3         NaN        NaN   NaN        NaN    ...     2.892042  0.547547
# 4         NaN        NaN   NaN        NaN    ...     2.113563  0.547547
#
# ...

# %%
q  = """
SELECT patient_id,
min(encounter_id) as minencounter_id, max(encounter_id) as maxencounter_id, 
min(time) as mintime, max(time) as maxtime, 
min(loc_cat) as minloc_cat, max(loc_cat) as maxloc_cat, 
max(IVF_meds) as maxIVF_meds, sum(IVF_meds) as sumIVF_meds,
max(IVF_volume) as maxIVF_volume, sum(IVF_volume) as sumIVF_volume, 
max(IV_intake) as maxIV_intake, sum(IV_intake) as sumIV_intake, 
max(fio2) as maxfio2, sum(fio2) as sumfio2, 
max(fio2_vent) as maxfio2_vent, sum(fio2_vent) as sumfio2_vent, 
max(gastric_output) as maxgastric_output, sum(gastric_output) as sumgastric_output, 
max(gcs_eye) as maxgcs_eye, sum(gcs_eye) as sumgcs_eye, 
max(gcs_motor) as maxgcs_motor, sum(gcs_motor) as sumgcs_motor, 
max(gcs_score) as maxgcs_score, sum(gcs_score) as sumgcs_score, 
max(gcs_verbal) as maxgcs_verbal, sum(gcs_verbal) as sumgcs_verbal, 
max(hfo_fio2) as maxhfo_fio2, sum(hfo_fio2) as sumhfo_fio2, 
max(map_notcalc) as maxmap_notcalc, sum(map_notcalc) as summap_notcalc, 
max(map_zzz) as maxmap_zzz, sum(map_zzz) as summap_zzz, 
max(nasal_cannula) as maxnasal_cannula, sum(nasal_cannula) as sumnasal_cannula, 
max(ni_fio2) as maxni_fio2, sum(ni_fio2) as sumni_fio2, 
max(ni_vent) as maxni_vent, sum(ni_vent) as sumni_vent, 
max(o2_device) as maxo2_device, sum(o2_device) as sumo2_device, 
max(o2_flow) as maxo2_flow, sum(o2_flow) as sumo2_flow, 
max(rass) as maxrass, sum(rass) as sumrass, 
max(roomair) as maxroomair, sum(roomair) as sumroomair, 
max(temp) as maxtemp, sum(temp) as sumtemp, 
max(tube_output) as maxtube_output, sum(tube_output) as sumtube_output, 
max(wound_output) as maxwound_output, sum(wound_output) as sumwound_output, 
max(fio2_final) as maxfio2_final, sum(fio2_final) as sumfio2_final, 
max(fio2_final2) as maxfio2_final2, sum(fio2_final2) as sumfio2_final2, 
max(sf_ratio_old) as maxsf_ratio_old, sum(sf_ratio_old) as sumsf_ratio_old, 
max(contam_true) as maxcontam_true, sum(contam_true) as sumcontam_true, 
max(staph) as maxstaph, sum(staph) as sumstaph, 
max(abs_bands) as maxabs_bands, sum(abs_bands) as sumabs_bands, 
max(abs_neutrophils) as maxabs_neutrophils, sum(abs_neutrophils) as sumabs_neutrophils, 
max(alt) as maxalt, sum(alt) as sumalt, 
max(antitrypsin) as maxantitrypsin, sum(antitrypsin) as sumantitrypsin, 
max(auto_abs_neutrophils) as maxauto_abs_neutrophils, sum(auto_abs_neutrophils) as sumauto_abs_neutrophils, 
max(bands) as maxbands, sum(bands) as sumbands, 
max(basophils) as maxbasophils, sum(basophils) as sumbasophils, 
max(blasts) as maxblasts, sum(blasts) as sumblasts, 
min(cdiff) as mincdiff, max(cdiff) as maxcdiff, sum(cdiff) as sumcdiff, 
max(chloride) as maxchloride, sum(chloride) as sumchloride, 
max(cortisol) as maxcortisol, sum(cortisol) as sumcortisol, 
max(crp) as maxcrp, sum(crp) as sumcrp, 
max(cul_cathtip) as maxcul_cathtip, sum(cul_cathtip) as sumcul_cathtip, 
max(cul_csf) as maxcul_csf, sum(cul_csf) as sumcul_csf, 
max(cul_influenza) as maxcul_influenza, sum(cul_influenza) as sumcul_influenza, 
max(cul_mrsa) as maxcul_mrsa, sum(cul_mrsa) as sumcul_mrsa, 
max(cul_parainfluenza) as maxcul_parainfluenza, sum(cul_parainfluenza) as sumcul_parainfluenza, 
max(cul_resp) as maxcul_resp, sum(cul_resp) as sumcul_resp, 
max(eosinophils) as maxeosinophils, sum(eosinophils) as sumeosinophils, 
max(esr) as maxesr, sum(esr) as sumesr, 
max(hb1198) as maxhb1198, sum(hb1198) as sumhb1198, 
max(hb1200) as maxhb1200, sum(hb1200) as sumhb1200, 
max(hc03) as maxhc03, sum(hc03) as sumhc03, 
max(hc03_ven) as maxhc03_ven, sum(hc03_ven) as sumhc03_ven, 
max(hco3_art) as maxhco3_art, sum(hco3_art) as sumhco3_art, 
max(hematocrit) as maxhematocrit, sum(hematocrit) as sumhematocrit, 
max(inr) as maxinr, sum(inr) as suminr, 
max(ketones) as maxketones, sum(ketones) as sumketones, 
max(lactate1) as maxlactate1, sum(lactate1) as sumlactate1, 
max(lactate_wholebld1434) as maxlactate_wholebld1434, sum(lactate_wholebld1434) as sumlactate_wholebld1434, 
max(lactate_wholebld4303) as maxlactate_wholebld4303, sum(lactate_wholebld4303) as sumlactate_wholebld4303, 
max(lactic_acid) as maxlactic_acid, sum(lactic_acid) as sumlactic_acid, 
max(lipase) as maxlipase, sum(lipase) as sumlipase, 
max(lymphocytes) as maxlymphocytes, sum(lymphocytes) as sumlymphocytes, 
max(magnesium) as maxmagnesium, sum(magnesium) as summagnesium, 
max(mcv) as maxmcv, sum(mcv) as summcv, 
max(metamyelocytes) as maxmetamyelocytes, sum(metamyelocytes) as summetamyelocytes, 
max(monocytes) as maxmonocytes, sum(monocytes) as summonocytes, 
max(neutrophils) as maxneutrophils, sum(neutrophils) as sumneutrophils, 
max(nrbc) as maxnrbc, sum(nrbc) as sumnrbc, 
max(osmolality) as maxosmolality, sum(osmolality) as sumosmolality, 
max(paco2) as maxpaco2, sum(paco2) as sumpaco2, 
max(pao2) as maxpao2, sum(pao2) as sumpao2, 
max(pco2_1097) as maxpco2_1097, sum(pco2_1097) as sumpco2_1097, 
max(pco2_4098) as maxpco2_4098, sum(pco2_4098) as sumpco2_4098, 
max(ph1250) as maxph1250, sum(ph1250) as sumph1250, 
max(ph1819) as maxph1819, sum(ph1819) as sumph1819, 
max(ph272) as maxph272, sum(ph272) as sumph272, 
max(ph4315) as maxph4315, sum(ph4315) as sumph4315, 
max(ph690) as maxph690, sum(ph690) as sumph690, 
max(phosphate) as maxphosphate, sum(phosphate) as sumphosphate, 
max(potassium) as maxpotassium, sum(potassium) as sumpotassium, 
max(promyelocytes) as maxpromyelocytes, sum(promyelocytes) as sumpromyelocytes, 
max(total_protein) as maxtotal_protein, sum(total_protein) as sumtotal_protein, 
max(ptt) as maxptt, sum(ptt) as sumptt, 
max(pvco2) as maxpvco2, sum(pvco2) as sumpvco2, 
max(pvo2) as maxpvo2, sum(pvo2) as sumpvo2, 
max(rbc) as maxrbc, sum(rbc) as sumrbc, 
max(rdw) as maxrdw, sum(rdw) as sumrdw, 
max(svo2_2641) as maxsvo2_2641, sum(svo2_2641) as sumsvo2_2641, 
max(svo2_4351) as maxsvo2_4351, sum(svo2_4351) as sumsvo2_4351, 
max(troponin_old) as maxtroponin_old, sum(troponin_old) as sumtroponin_old, 
max(lactate) as maxlactate, sum(lactate) as sumlactate, 

min(enc_eio) as minenc_eio, max(enc_eio) as maxenc_eio, sum(enc_eio) as sumenc_eio, 
min(discharge_dispo) as mindischarge_dispo, max(discharge_dispo) as maxdischarge_dispo, sum(discharge_dispo) as sumdischarge_dispo, 
min(bmi) as minbmi, max(bmi) as maxbmi, sum(bmi) as sumbmi, 
min(time_start) as mintime_start, max(time_start) as maxtime_start, sum(time_start) as sumtime_start, 
min(time_end) as mintime_end, max(time_end) as maxtime_end, sum(time_end) as sumtime_end, 
min(time_adm) as mintime_adm, max(time_adm) as maxtime_adm, sum(time_adm) as sumtime_adm, 
min(time_disch) as mintime_disch, max(time_disch) as maxtime_disch, sum(time_disch) as sumtime_disch, 
min(race) as minrace, max(race) as maxrace, sum(race) as sumrace, 
min(ethnicity) as minethnicity, max(ethnicity) as maxethnicity, sum(ethnicity) as sumethnicity, 
max(sex) as maxsex,

max(admission_order) as maxadmission_order, sum(admission_order) as sumadmission_order, 
max(ct_chestabdpelviswo) as maxct_chestabdpelviswo, sum(ct_chestabdpelviswo) as sumct_chestabdpelviswo, 
max(ct_chesupabd) as maxct_chesupabd, sum(ct_chesupabd) as sumct_chesupabd, 
max(sitter_order) as maxsitter_order, sum(sitter_order) as sumsitter_order, 
max(transcryo) as maxtranscryo, sum(transcryo) as sumtranscryo, 
max(transfer_order) as maxtransfer_order, sum(transfer_order) as sumtransfer_order, 
max(transffp) as maxtransffp, sum(transffp) as sumtransffp, 
max(transplts) as maxtransplts, sum(transplts) as sumtransplts, 
max(transrbc) as maxtransrbc, sum(transrbc) as sumtransrbc, 
max(transrbc_eq1) as maxtransrbc_eq1, sum(transrbc_eq1) as sumtransrbc_eq1, 
max(transrbc_gt1) as maxtransrbc_gt1, sum(transrbc_gt1) as sumtransrbc_gt1, 
max(reason) as maxreason, sum(reason) as sumreason, 
max(treatment_limit) as maxtreatment_limit, sum(treatment_limit) as sumtreatment_limit, 
max(drip_dexmedetomidine) as maxdrip_dexmedetomidine, sum(drip_dexmedetomidine) as sumdrip_dexmedetomidine, 
max(drip_dobutamine) as maxdrip_dobutamine, sum(drip_dobutamine) as sumdrip_dobutamine, 
max(drip_dopamine) as maxdrip_dopamine, sum(drip_dopamine) as sumdrip_dopamine, 
max(drip_fentanyl) as maxdrip_fentanyl, sum(drip_fentanyl) as sumdrip_fentanyl, 
max(drip_midazolam) as maxdrip_midazolam, sum(drip_midazolam) as sumdrip_midazolam, 
max(drip_milrinone) as maxdrip_milrinone, sum(drip_milrinone) as sumdrip_milrinone, 
max(drip_morphine) as maxdrip_morphine, sum(drip_morphine) as sumdrip_morphine, 
max(drip_norepinephrine) as maxdrip_norepinephrine, sum(drip_norepinephrine) as sumdrip_norepinephrine, 
max(drip_phenylephrine) as maxdrip_phenylephrine, sum(drip_phenylephrine) as sumdrip_phenylephrine, 
max(drip_propofol) as maxdrip_propofol, sum(drip_propofol) as sumdrip_propofol, 
max(drip_vasopressin) as maxdrip_vasopressin, sum(drip_vasopressin) as sumdrip_vasopressin, 
max(pain_scale) as maxpain_scale, sum(pain_scale) as sumpain_scale, 
max(dialysis) as maxdialysis, sum(dialysis) as sumdialysis, 
max(peritoneal) as maxperitoneal, sum(peritoneal) as sumperitoneal, 
max(braden_activity) as maxbraden_activity, sum(braden_activity) as sumbraden_activity, 
max(braden_friction) as maxbraden_friction, sum(braden_friction) as sumbraden_friction, 
max(braden_mobility) as maxbraden_mobility, sum(braden_mobility) as sumbraden_mobility, 
max(braden_moisture) as maxbraden_moisture, sum(braden_moisture) as sumbraden_moisture, 
min(braden_nutrition) as minbraden_nutrition, max(braden_nutrition) as maxbraden_nutrition, sum(braden_nutrition) as sumbraden_nutrition, 
max(braden_scale) as maxbraden_scale, sum(braden_scale) as sumbraden_scale, 
max(braden_sensory) as maxbraden_sensory, sum(braden_sensory) as sumbraden_sensory, 
max(morse_ambaid) as maxmorse_ambaid, sum(morse_ambaid) as summorse_ambaid, 
max(morse_dateoffall) as maxmorse_dateoffall, sum(morse_dateoffall) as summorse_dateoffall, 
max(morse_fallhistory) as maxmorse_fallhistory, sum(morse_fallhistory) as summorse_fallhistory, 
max(morse_gaittransfer) as maxmorse_gaittransfer, sum(morse_gaittransfer) as summorse_gaittransfer, 
max(morse_ivdevice) as maxmorse_ivdevice, sum(morse_ivdevice) as summorse_ivdevice, 
max(morse_mentalstatus) as maxmorse_mentalstatus, sum(morse_mentalstatus) as summorse_mentalstatus, 
max(morse_score) as maxmorse_score, sum(morse_score) as summorse_score, 
max(morse_secdiag) as maxmorse_secdiag, sum(morse_secdiag) as summorse_secdiag, 
max(cart) as maxcart, sum(cart) as sumcart, 
max(cart_loc) as maxcart_loc, sum(cart_loc) as sumcart_loc, 
max(initialrhythm) as maxinitialrhythm, sum(initialrhythm) as suminitialrhythm, 
max(rosc) as maxrosc, sum(rosc) as sumrosc, 
max(rrt) as maxrrt, sum(rrt) as sumrrt, 
max(wardorICU) as maxwardorICU, sum(wardorICU) as sumwardorICU, 
max(everwardorICU) as maxeverwardorICU, sum(everwardorICU) as sumeverwardorICU, 
max(troponin_flag) as maxtroponin_flag, sum(troponin_flag) as sumtroponin_flag, 
max(troponin) as maxtroponin, sum(troponin) as sumtroponin, 
max(troponin_bin) as maxtroponin_bin, sum(troponin_bin) as sumtroponin_bin, 
max(ct_lowextrem_w) as maxct_lowextrem_w, sum(ct_lowextrem_w) as sumct_lowextrem_w, 
max(ct_lowextrem_wo) as maxct_lowextrem_wo, sum(ct_lowextrem_wo) as sumct_lowextrem_wo, 
max(ct_w_contrast) as maxct_w_contrast, sum(ct_w_contrast) as sumct_w_contrast, 
max(ct_wo_contrast) as maxct_wo_contrast, sum(ct_wo_contrast) as sumct_wo_contrast, 
max(bipap) as maxbipap, sum(bipap) as sumbipap, 
max(cpap) as maxcpap, sum(cpap) as sumcpap, 
max(trach) as maxtrach, sum(trach) as sumtrach, 
max(hfnc) as maxhfnc, sum(hfnc) as sumhfnc, 
max(other_o2device) as maxother_o2device, sum(other_o2device) as sumother_o2device, 
max(fio2_finaltest) as maxfio2_finaltest, sum(fio2_finaltest) as sumfio2_finaltest, 
max(fio2_final3) as maxfio2_final3, sum(fio2_final3) as sumfio2_final3, 
max(sf_ratio) as maxsf_ratio, sum(sf_ratio) as sumsf_ratio, 
max(suction_1hour_trigger) as maxsuction_1hour_trigger, sum(suction_1hour_trigger) as sumsuction_1hour_trigger, 
max(suction_route_rt) as maxsuction_route_rt, sum(suction_route_rt) as sumsuction_route_rt, 
max(suction_route2_nur) as maxsuction_route2_nur, sum(suction_route2_nur) as sumsuction_route2_nur, 
max(suction_zzz) as maxsuction_zzz, sum(suction_zzz) as sumsuction_zzz, 
max(ruq_ultrasound01) as maxruq_ultrasound01, sum(ruq_ultrasound01) as sumruq_ultrasound01, 
max(ammonia) as maxammonia, sum(ammonia) as sumammonia, 

min(abdominal_assess) as minabdominal_assess, max(abdominal_assess) as maxabdominal_assess, sum(abdominal_assess) as sumabdominal_assess, 
min(cardiac_rhythm) as mincardiac_rhythm, max(cardiac_rhythm) as maxcardiac_rhythm, sum(cardiac_rhythm) as sumcardiac_rhythm, 
max(lvad) as maxlvad, sum(lvad) as sumlvad, 
min(med_name) as minmed_name, max(med_name) as maxmed_name, sum(med_name) as summed_name, 
max(sedative_icu) as maxsedative_icu, sum(sedative_icu) as sumsedative_icu, 
max(vasoactive) as maxvasoactive, sum(vasoactive) as sumvasoactive, 
max(inotrope) as maxinotrope, sum(inotrope) as suminotrope, 
max(nebtrt) as maxnebtrt, sum(nebtrt) as sumnebtrt, 
max(ivbolus) as maxivbolus, sum(ivbolus) as sumivbolus, 
max(ivbolus_lr) as maxivbolus_lr, sum(ivbolus_lr) as sumivbolus_lr, 
max(ivbolus_nacl) as maxivbolus_nacl, sum(ivbolus_nacl) as sumivbolus_nacl, 
max(ivbolus_alb) as maxivbolus_alb, sum(ivbolus_alb) as sumivbolus_alb, 
max(hypoglycemic_ins) as maxhypoglycemic_ins, sum(hypoglycemic_ins) as sumhypoglycemic_ins, 
max(lactulose) as maxlactulose, sum(lactulose) as sumlactulose, 
max(irb_drug) as maxirb_drug, sum(irb_drug) as sumirb_drug, 
max(aed_med) as maxaed_med, sum(aed_med) as sumaed_med, 
max(vitals_time) as maxvitals_time, sum(vitals_time) as sumvitals_time, 
max(first_vitals_time) as maxfirst_vitals_time, sum(first_vitals_time) as sumfirst_vitals_time, 
max(last_vitals_time) as maxlast_vitals_time, sum(last_vitals_time) as sumlast_vitals_time, 
max(expired) as maxexpired, sum(expired) as sumexpired, 
max(died01) as maxdied01, sum(died01) as sumdied01, 
max(died_ever) as maxdied_ever, sum(died_ever) as sumdied_ever, 
max(los) as maxlos, sum(los) as sumlos, 
max(icd9_477_x) as maxicd9_477_x, sum(icd9_477_x) as sumicd9_477_x, 
max(icd9_691_x) as maxicd9_691_x, sum(icd9_691_x) as sumicd9_691_x, 
max(icd9_493_x) as maxicd9_493_x, sum(icd9_493_x) as sumicd9_493_x, 
max(icd9_995_3) as maxicd9_995_3, sum(icd9_995_3) as sumicd9_995_3, 
max(icd9_558_3) as maxicd9_558_3, sum(icd9_558_3) as sumicd9_558_3, 
max(route) as maxroute, sum(route) as sumroute, 
max(sepsis_glucocorticoid) as maxsepsis_glucocorticoid, sum(sepsis_glucocorticoid) as sumsepsis_glucocorticoid, 
max(sepsis_antibiotic) as maxsepsis_antibiotic, sum(sepsis_antibiotic) as sumsepsis_antibiotic, 
max(encounter_masterdata) as maxencounter_masterdata, sum(encounter_masterdata) as sumencounter_masterdata, 
max(infxnqsofa) as maxinfxnqsofa, sum(infxnqsofa) as suminfxnqsofa, 
max(los_total) as maxlos_total, sum(los_total) as sumlos_total, 
max(age) as maxage, 
max(temp_c) as maxtemp_c, sum(temp_c) as sumtemp_c, 
max(icu_flag) as maxicu_flag, sum(icu_flag) as sumicu_flag, 
max(num_icustays) as maxnum_icustays, sum(num_icustays) as sumnum_icustays, 
max(temp_c_ecart) as maxtemp_c_ecart, sum(temp_c_ecart) as sumtemp_c_ecart, 
max(potassium_ecart) as maxpotassium_ecart, sum(potassium_ecart) as sumpotassium_ecart, 
max(ecart_score) as maxecart_score, sum(ecart_score) as sumecart_score, 
max(pao2_sofa) as maxpao2_sofa, sum(pao2_sofa) as sumpao2_sofa, 
max(fio2_final3_sofa) as maxfio2_final3_sofa, sum(fio2_final3_sofa) as sumfio2_final3_sofa, 
max(gcs_score_sofa) as maxgcs_score_sofa, sum(gcs_score_sofa) as sumgcs_score_sofa, 
max(sofa_resp) as maxsofa_resp, sum(sofa_resp) as sumsofa_resp, 
max(sofa_coag) as maxsofa_coag, sum(sofa_coag) as sumsofa_coag, 
max(sofa_bili) as maxsofa_bili, sum(sofa_bili) as sumsofa_bili, 
max(sofa_card) as maxsofa_card, sum(sofa_card) as sumsofa_card, 
max(sofa_gcs) as maxsofa_gcs, sum(sofa_gcs) as sumsofa_gcs, 
max(sofa_cr) as maxsofa_cr, sum(sofa_cr) as sumsofa_cr, 
max(sofa_score) as maxsofa_score, sum(sofa_score) as sumsofa_score, 
max(encount_enum) as maxencount_enum, sum(encount_enum) as sumencount_enum, 
max(antibiotic_ad) as maxantibiotic_ad, 
max(antiarrhythmic_ad) as maxantiarrhythmic_ad, 
max(anticoag_ad) as maxanticoag_ad, 
max(antipsych_ad) as maxantipsych_ad, 
max(avnodal_ad) as maxavnodal_ad, 
max(diuretic_ad) as maxdiuretic_ad, 
max(fungal_ad) as maxfungal_ad, 
max(hypogly_ad) as maxhypogly_ad, 
max(immuno_ad) as maximmuno_ad, 
max(steroid_ad) as maxsteroid_ad, 
max(antiviral_ad) as maxantiviral_ad, 
sum(chest_xray) as sumchest_xray, 
sum(chestab_w_ct) as sumchestab_w_ct, 
sum(chestab_wo_ct) as sumchestab_wo_ct, 
sum(headneck_w_ct) as sumheadneck_w_ct, 
max(cul_blood_ord) as maxcul_blood_ord, 
max(cul_urine_ord) as maxcul_urine_ord, 
max(cul_other_ord) as maxcul_other_ord, 
max(cul_stool_ord) as maxcul_stool_ord, 
sum(elix_comorb) as sumelix_comorb, 
max(urin_cath) as maxurin_cath, 
sum(urin_output) as sumurin_output, 
sum(mech_ventil) as summech_ventil, 
max(benzo_diaz) as maxbenzo_diaz, 
max(end_of_life) as maxend_of_life, 
max(ekg_ecg) as maxekg_ecg, 
max(central_line) as maxcentral_line, 
sum(mob_lo) as summob_lo, 
max(age_yr) as maxage_yr, 
max(albumin_c) as maxalbumin_c, 
max(allphos_c) as maxallphos_c, 
max(avpu_c) as maxavpu_c, 
max(bun_c) as maxbun_c, 
max(bun_cr_c) as maxbun_cr_c, 
max(calcium_c) as maxcalcium_c, 
max(co2_c) as maxco2_c, 
max(creatinine_c) as maxcreatinine_c, 
max(dbp_c) as maxdbp_c, 
max(gluc_ser_c) as maxgluc_ser_c, 
max(hb_c) as maxhb_c, 
max(o2sat_c) as maxo2sat_c, 
max(platelet_count_c) as maxplatelet_count_c, 
max(ppi_c) as maxppi_c, 
max(rr_c) as maxrr_c, 
max(sbp_c) as maxsbp_c, 
max(sgot_c) as maxsgot_c, 
max(sodium_c) as maxsodium_c, 
max(wbc_c) as maxwbc_c
FROM sepsis_data
GROUP BY patient_id;
"""

df = pysqldf(q)
print df.head()
