# %%
#EDITED VERSION OF JAY'S PANDASQL

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
import pandas as pd
import pandasql

#filename = 'condensed_sepsis.csv'
sepsis_data = pd.DataFrame.from_csv('condensed_sepsis.csv', index_col=None)
print(sepsis_data.columns)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (149,150,175) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# Index(['Unnamed: 0', 'patient_id', 'encounter_id', 'time', 'loc_cat',
#        'IVF_meds', 'IVF_volume', 'IV_intake', 'fio2', 'fio2_vent',
#        ...
#        'hb_c', 'o2sat_c', 'platelet_count_c', 'ppi_c', 'rr_c', 'sbp_c',
#        'sgot_c', 'sodium_c', 'wbcecart', 'wbc_c'],
#       dtype='object', length=278)

# %%
for column in sepsis_data:
    if column in ['IVF_meds', 			'fio2', 	'fio2_vent', 	'gastric_output', 	'gcs_eye', 	'gcs_motor', 	'gcs_score', 	'gcs_verbal', 'map_notcalc', 	'map_zzz', 		'ni_fio2', 			'o2_flow', 	'rass', 		'temp', 	'tube_output', 	'wound_output', 	'fio2_final', 	'fio2_final2', 	'sf_ratio_old', 			'abs_bands', 	'abs_neutrophils', 	'alt', 	'antitrypsin', 		'bands', 	'basophils', 	'blasts', 		'chloride', 	'cortisol','eosinophils', 	'esr', 	'hb1198', 	'hb1200', 		'hc03_ven', 	'hco3_art', 	'hematocrit', 	'inr', 	'ketones', 		'lactate_wholebld1434', 		'lactic_acid', 	'lipase', 	'lymphocytes', 	'magnesium', 	'mcv', 	'metamyelocytes', 	'monocytes', 	'neutrophils', 	'nrbc', 	'osmolality', 	'paco2', 	'pao2', 			'ph1250', 	'ph1819', 	'ph272', 			'phosphate', 	'potassium', 	'promyelocytes', 	'total_protein', 	'ptt', 	'pvco2', 	'pvo2', 	'rbc', 	'rdw', 	'svo2_2641', 		'troponin_old', 	'lactate', 			'bmi', 'drip_dexmedetomidine', 	'drip_dobutamine', 	'drip_dopamine', 	'drip_fentanyl', 	'drip_midazolam', 	'drip_milrinone', 	'drip_morphine', 	'drip_norepinephrine', 	'drip_phenylephrine', 	'drip_propofol', 	'drip_vasopressin', 	'pain_scale', 			'braden_activity', 	'braden_friction', 	'braden_mobility', 	'braden_moisture', 	'braden_nutrition', 	'braden_scale', 	'braden_sensory', 	'morse_ambaid', 		'morse_fallhistory', 	'morse_gaittransfer', 	'morse_ivdevice', 	'morse_mentalstatus', 	'morse_score', 	'morse_secdiag', 				'rosc', 					'troponin', 	'troponin_bin', 										'fio2_finaltest', 	'fio2_final3', 	'sf_ratio', 'los', 											'los_total', 	'temp_c', 		'num_icustays', 	'temp_c_ecart', 	'potassium_ecart', 	'ecart_score', 	'pao2_sofa', 	'fio2_final3_sofa', 	'gcs_score_sofa', 'sofa_coag', 	'sofa_bili', 	'sofa_card', 	'sofa_gcs', 	'sofa_cr', 	'sofa_score', 	'encount_enum', 	'antibiotic_ad', 	'antiarrhythmic_ad', 	'anticoag_ad', 	'antipsych_ad', 	'avnodal_ad', 	'diuretic_ad', 	'fungal_ad', 	'hypogly_ad', 	'hpogly_ad', 	'immuno_ad', 	'steroid_ad', 	'antiviral_ad', 	'chest_xray', 	'chestab_w_ct', 	'chestab_wo_ct', 	'headneck_w_ct', 	'cul_blood_ord', 	'cul_urine_ord', 	'cul_other_ord', 	'cul_stool_ord', 	'elix_comorb', 	'urin_cath', 	'urin_output', 	'mech_ventil', 	'benzo_diaz', 		'ekg_ecg', 	'central_line', 	'mob_lo', 	'age_yr', 	'albumin_c', 	'allphos_c', 	'avpu_c', 	'bun_c', 	'bun_cr_c', 	'calcium_c', 	'co2_c', 	'creatinine_c', 	'dbp_c', 	'gluc_ser_c', 	'hb_c', 	'o2sat_c', 	'platelet_count_c', 	'ppi_c', 	'rr_c', 	'sbp_c', 	'sgot_c', 	'sodium_c','wbc_c']:
        print(column)
        
        avg = sepsis_data[column].mean()
        stddev = sepsis_data[column].std()
        
        print(avg)
        print(stddev)
                
        sepsis_data[column] = sepsis_data[column].transform(lambda x: (x - avg) / stddev)
# Out:
# IVF_meds
# 121.91303135290873
# 541.0210620989119
# fio2
# 54.02530712530712
# 20.46539483227786
# fio2_vent
# 55.45666116914055
# 29.204023696525265
# gastric_output
# 133.43793445878848
# 238.76057504897545
# gcs_eye
# 3.1399097356544163
# 1.12124343055233
# gcs_motor
# 4.774436090225564
# 1.6700393414630983
# gcs_score
# 11.064861012116893
# 4.252975600764369
# gcs_verbal
# 3.19106529209622
# 1.780005843768377
# map_notcalc
# 78.24159045725646
# 21.574949627353732
# map_zzz
# 86.05321241258741
# 16.40725911794656
# ni_fio2
# 57.586021505376344
# 26.832526012176523
# o2_flow
# 8.869784615384615
# 17.424314890396413
# rass
# -2.078364565587734
# 1.5463265217349393
# temp
# 98.10059046125644
# 1.784817527386366
# tube_output
# 30.355371900826448
# 92.97593700399287
# wound_output
# 180.9375
# 346.0617840907484
# fio2_final
# 35.70341948663292
# 20.52498972594684
# fio2_final2
# 35.70341948663292
# 20.52498972594684
# sf_ratio_old
# 3.261557444522308
# 1.2829891126382804
# abs_bands
# ...

# %%
q  = """
SELECT patient_id, 
encounter_id, 
min(time) as mintime, max(time) as maxtime, 
count(loc_cat) as loc_cat, 
max(IVF_meds) as maxIVF_meds, count(IVF_meds) as countIVF_meds, 
max(IVF_volume) as maxIVF_volume, avg(IVF_volume) as avgIVF_volume, 
max(IV_intake) as maxIV_intake,
max(fio2) as maxfio2, avg(fio2) as avgfio2, 
max(fio2_vent) as maxfio2_vent, avg(fio2_vent) as avgfio2_vent, 
max(gastric_output) as maxgastric_output, min(gastric_output) as mingastric_output, avg(gastric_output) as avggastric_output, 
max(gcs_eye) as maxgcs_eye, min(gcs_eye) as mingcs_eye, 
max(gcs_motor) as maxgcs_motor, min(gcs_motor) as mingcs_motor, 
max(gcs_score) as maxgcs_score, avg(gcs_score) as avggcs_score, 
max(gcs_verbal) as maxgcs_verbal, min(gcs_verbal) as mingcs_verbal, 
max(hfo_fio2) as maxhfo_fio2, avg(hfo_fio2) as avghfo_fio2, 
max(map_notcalc) as maxmap_notcalc, min(map_notcalc) as minmap_notcalc, avg(map_notcalc) as avgmap_notcalc, 
max(map_zzz) as maxmap_zzz, min(map_zzz) as minmap_zzz, avg(map_zzz) as avgmap_zzz, 
max(nasal_cannula) as maxnasal_cannula, 
max(ni_fio2) as maxni_fio2, avg(ni_fio2) as avgni_fio2, 
max(ni_vent) as maxni_vent, 
max(o2_device) as maxo2_device, 
max(o2_flow) as maxo2_flow, min(o2_flow) as mino2_flow, avg(o2_flow) as avgo2_flow, 
max(rass) as maxrass, min(rass) as minrass, avg(rass) as avgrass, 
max(roomair) as maxroomair, 
min(temp) as mintemp, max(temp) as maxtemp, 
max(tube_output) as maxtube_output, avg(tube_output) as avgtube_output, 
max(wound_output) as maxwound_output, avg(wound_output) as avgwound_output, 
max(fio2_final) as maxfio2_final, 
max(fio2_final2) as maxfio2_final2, 
max(sf_ratio_old) as maxsf_ratio_old, avg(sf_ratio_old) as avgsf_ratio_old, 
max(contam_true) as maxcontam_true, 
max(staph) as maxstaph, 
max(abs_bands) as maxabs_bands, min(abs_bands) as minabs_bands, avg(abs_bands) as avgabs_bands, 
max(abs_neutrophils) as maxabs_neutrophils, max(abs_neutrophils) as maxabs_neutrophils, avg(abs_neutrophils) as avgabs_neutrophils, 
max(alt) as maxalt, min(alt) as minalt, avg(alt) as avgalt, 
max(antitrypsin) as maxantitrypsin, avg(antitrypsin) as avgantitrypsin, 
max(auto_abs_neutrophils) as maxauto_abs_neutrophils, min(auto_abs_neutrophils) as minauto_abs_neutrophils, 
max(bands) as maxbands, min(bands) as minbands, avg(bands) as avgbands, 
max(basophils) as maxbasophils, min(basophils) as minbasophils, avg(basophils) as avgbasophils, 
max(blasts) as maxblasts, min(blasts) as minblasts, avg(blasts) as avgblasts, 
min(cdiff) as mincdiff, max(cdiff) as maxcdiff, sum(cdiff) as sumcdiff, 
max(chloride) as maxchloride, min(chloride) as minchloride, avg(chloride) as avgchloride, 
max(cortisol) as maxcortisol, min(cortisol) as mincortisol, avg(cortisol) as avgcortisol, 
max(crp) as maxcrp, min(crp) as mincrp, avg(crp) as avgcrp, 
max(cul_cathtip) as maxcul_cathtip, 
max(cul_csf) as maxcul_csf, 
max(cul_influenza) as maxcul_influenza, 
max(cul_mrsa) as maxcul_mrsa, 
max(cul_parainfluenza) as maxcul_parainfluenza, 
max(cul_resp) as maxcul_resp, 
max(eosinophils) as maxeosinophils, avg(eosinophils) as avgeosinophils, 
max(esr) as maxesr, avg(esr) as avgesr, 
max(hb1198) as maxhb1198, avg(hb1198) as avghb1198, 
max(hb1200) as maxhb1200, avg(hb1200) as avghb1200, 
max(hc03) as maxhc03, 
max(hc03_ven) as maxhc03_ven, avg(hc03_ven) as avghc03_ven, 
max(hco3_art) as maxhco3_art, 
max(hematocrit) as maxhematocrit, min(hematocrit) as minhematocrit, avg(hematocrit) as avghematocrit, 
max(inr) as maxinr, avg(inr) as avginr, 
max(ketones) as maxketones, min(ketones) as minketones, avg(ketones) as avgketones, 
max(lactate1) as maxlactate1, avg(lactate1) as avglactate1, 
max(lactate_wholebld1434) as maxlactate_wholebld1434, avg(lactate_wholebld1434) as avglactate_wholebld1434, 
max(lactate_wholebld4303) as maxlactate_wholebld4303, avg(lactate_wholebld4303) as avglactate_wholebld4303, 
max(lactic_acid) as maxlactic_acid, min(lactic_acid) as minlactic_acid, avg(lactic_acid) as avglactic_acid, 
max(lipase) as maxlipase, min(lipase) as minlipase, avg(lipase) as lipase, 
max(lymphocytes) as maxlymphocytes, min(lymphocytes) as minlymphocytes, avg(lymphocytes) as avglymphocytes, 
max(magnesium) as maxmagnesium, min(magnesium) as minmagnesium, avg(magnesium) as avgmagnesium, 
max(mcv) as maxmcv, avg(mcv) as avgmcv, 
max(metamyelocytes) as maxmetamyelocytes, min(metamyelocytes) as minmetamyelocytes, avg(metamyelocytes) as avgmetamyelocytes, 
max(monocytes) as maxmonocytes, min(monocytes) as minmonocytes, avg(monocytes) as avgmonocytes, 
max(neutrophils) as maxneutrophils, min(neutrophils) as minneutrophils, avg(neutrophils) as avgneutrophils, 
max(nrbc) as maxnrbc, avg(nrbc) as avgnrbc, 
max(osmolality) as maxosmolality, min(osmolality) as minosmolality, avg(osmolality) as avgosmolality, 
max(paco2) as maxpaco2, avg(paco2) as avgpaco2, 
max(pao2) as maxpao2, avg(pao2) as avgpao2, 
max(pco2_1097) as maxpco2_1097, 
max(pco2_4098) as maxpco2_4098, 
max(ph1250) as maxph1250, avg(ph1250) as avgph1250, 
max(ph1819) as maxph1819, avg(ph1819) as avgph1819, 
max(ph272) as maxph272, avg(ph272) as avgph272, 
max(ph4315) as maxph4315, avg(ph4315) as avgph4315, 
max(ph690) as maxph690, avg(ph690) as avgph690, 
max(phosphate) as maxphosphate, min(phosphate) as minphosphate, avg(phosphate) as avgphosphate,
max(potassium) as maxpotassium, min(potassium) as minpotassium, avg(potassium) as avgpotassium, 
max(promyelocytes) as maxpromyelocytes, avg(promyelocytes) as avgpromyelocytes, 
max(total_protein) as maxtotal_protein, avg(total_protein) as avgtotal_protein, 
max(ptt) as maxptt, min(ptt) as minptt, avg(ptt) as avgptt,
max(pvco2) as maxpvco2, min(pvco2) as minpvco2, max(pvco2) as maxpvo2,
max(pvo2) as maxpvo2, min(pvo2) as minpvo2, max(pvo2) as maxpvo2,
max(rbc) as maxrbc, min(rbc) as minrbc, avg(rbc) as avgrbc, 
max(rdw) as maxrdw, min(rdw) as minrdw, avg(rdw) as avgrdw, 
max(svo2_2641) as maxsvo2_2641, avg(svo2_2641) as avgsvo2_2641, 
max(svo2_4351) as maxsvo2_4351, avg(svo2_4351) as avgsvo2_4351, 
max(troponin_old) as maxtroponin_old, avg(troponin_old) as avgtroponin_old, 
max(lactate) as maxlactate, avg(lactate) as avglactate, 

max(enc_eio) as minenc_eio, count(enc_eio) as countenc_eio,  
group_concat(discharge_dispo) as concatdischarge_dispo, 
min(bmi) - max(bmi) as diffbmi, avg(bmi) as avgbmi, 
min(time_start) as mintime_start, max(time_start) as maxtime_start, 
min(time_end) as mintime_end, max(time_end) as maxtime_end,
min(time_adm) as mintime_adm, max(time_adm) as maxtime_adm, 
min(time_disch) as mintime_disch, max(time_disch) as maxtime_disch,
min(race) as minrace,
min(ethnicity) as minethnicity,
max(sex) as maxsex, 

max(admission_order) as maxadmission_order,
max(ct_chestabdpelviswo) as maxct_chestabdpelviswo,
max(ct_chesupabd) as maxct_chesupabd,
max(sitter_order) as maxsitter_order, 
max(transcryo) as maxtranscryo,
max(transfer_order) as maxtransfer_order,
max(transffp) as maxtransffp,
max(transplts) as maxtransplts,
max(transrbc) as maxtransrbc,
max(transrbc_eq1) as maxtransrbc_eq1, 
max(transrbc_gt1) as maxtransrbc_gt1, 
group_concat(reason) as concatreason,
max(treatment_limit) as maxtreatment_limit,
max(drip_dexmedetomidine) as maxdrip_dexmedetomidine, avg(drip_dexmedetomidine) as avgdrip_dexmedetomidine, 
max(drip_dobutamine) as maxdrip_dobutamine, avg(drip_dobutamine) as avgdrip_dobutamine, 
max(drip_dopamine) as maxdrip_dopamine, avg(drip_dopamine) as avgdrip_dopamine, 
max(drip_fentanyl) as maxdrip_fentanyl, avg(drip_fentanyl) as avgdrip_fentanyl, 
max(drip_midazolam) as maxdrip_midazolam, avg(drip_midazolam) as avgdrip_midazolam, 
max(drip_milrinone) as maxdrip_milrinone, avg(drip_milrinone) as avgdrip_milrinone, 
max(drip_morphine) as maxdrip_morphine, avg(drip_morphine) as avgdrip_morphine, 
max(drip_norepinephrine) as maxdrip_norepinephrine, avg(drip_norepinephrine) as avgdrip_norepinephrine, 
max(drip_phenylephrine) as maxdrip_phenylephrine, avg(drip_phenylephrine) as avgdrip_phenylephrine, 
max(drip_propofol) as maxdrip_propofol, avg(drip_propofol) as avgdrip_propofol, 
max(drip_vasopressin) as maxdrip_vasopressin, avg(drip_vasopressin) as avgdrip_vasopressin, 
max(pain_scale) as maxpain_scale, avg(pain_scale) as avgpain_scale, 
max(dialysis) as maxdialysis,
max(peritoneal) as maxperitoneal,
max(braden_activity) as maxbraden_activity, min(braden_activity) as minbraden_activity, 
max(braden_friction) as maxbraden_friction, min(braden_friction) as minbraden_friction, 
max(braden_mobility) as maxbraden_mobility, min(braden_mobility) as minbraden_mobility, 
max(braden_moisture) as maxbraden_moisture, min(braden_moisture) as minbraden_moisture, 
min(braden_nutrition) as minbraden_nutrition, max(braden_nutrition) as maxbraden_nutrition,  
max(braden_scale) as maxbraden_scale, avg(braden_scale) as avgbraden_scale, 
max(braden_sensory) as maxbraden_sensory, min(braden_sensory) as minbraden_sensory, 
max(morse_ambaid) as maxmorse_ambaid, min(morse_ambaid) as minmorse_ambaid, 
max(morse_dateoffall) as maxmorse_dateoffall, min(morse_dateoffall) as minmorse_dateoffall, 
max(morse_fallhistory) as maxmorse_fallhistory, min(morse_fallhistory) as minmorse_fallhistory, 
max(morse_gaittransfer) as maxmorse_gaittransfer, min(morse_gaittransfer) as minmorse_gaittransfer, 
max(morse_ivdevice) as maxmorse_ivdevice, min(morse_ivdevice) as minmorse_ivdevice, 
max(morse_mentalstatus) as maxmorse_mentalstatus, min(morse_mentalstatus) as minmorse_mentalstatus, 
max(morse_score) as maxmorse_score, avg(morse_score) as avgmorse_score, 
max(morse_secdiag) as maxmorse_secdiag, min(morse_secdiag) as mindatamorse_secdiag, 
count(cart) as countcart, 
count(cart_loc) as countcart_loc, group_concat(cart_loc) as concatcart_loc, 
group_concat(initialrhythm) as concatinitialrhythm, 
max(rosc) as maxrosc,
max(rrt) as maxrrt,
max(wardorICU) as maxwardorICU,
max(everwardorICU) as maxeverwardorICU, 
max(troponin_flag) as maxtroponin_flag,
max(troponin) as maxtroponin, sum(troponin) as sumtroponin, 
max(troponin_bin) as maxtroponin_bin, avg(troponin_bin) as avgtroponin_bin, 
max(ct_lowextrem_w) as maxct_lowextrem_w,
max(ct_lowextrem_wo) as maxct_lowextrem_wo,
max(ct_w_contrast) as maxct_w_contrast,
max(ct_wo_contrast) as maxct_wo_contrast, 
max(bipap) as maxbipap,
max(cpap) as maxcpap,
max(trach) as maxtrach,
max(hfnc) as maxhfnc,
max(other_o2device) as maxother_o2device, sum(other_o2device) as sumother_o2device, 
max(fio2_finaltest) as maxfio2_finaltest, 
max(fio2_final3) as maxfio2_final3,
max(sf_ratio) as maxsf_ratio, avg(sf_ratio) as avgsf_ratio, 
max(suction_1hour_trigger) as maxsuction_1hour_trigger,
max(suction_route_rt) as maxsuction_route_rt,
max(suction_route2_nur) as maxsuction_route2_nur, 
max(suction_zzz) as maxsuction_zzz, 
max(ruq_ultrasound01) as maxruq_ultrasound01, 
max(ammonia) as maxammonia, avg(ammonia) as avgammonia, 

group_concat(abdominal_assess) as concatabdominal_assess, count(abdominal_assess) as countabdominal_assess,  
group_concat(cardiac_rhythm) as mincardiac_rhythm, count(cardiac_rhythm) as maxcardiac_rhythm,
max(lvad) as maxlvad, 
group_concat(med_name) as minmed_name, count(med_name) as countmed_name, 
max(sedative_icu) as maxsedative_icu,
max(vasoactive) as maxvasoactive,
max(inotrope) as maxinotrope, 
max(nebtrt) as maxnebtrt,
max(ivbolus) as maxivbolus,
max(ivbolus_lr) as maxivbolus_lr,
max(ivbolus_nacl) as maxivbolus_nacl,
max(ivbolus_alb) as maxivbolus_alb,
max(hypoglycemic_ins) as maxhypoglycemic_ins,
max(lactulose) as maxlactulose, 
max(irb_drug) as maxirb_drug,
max(aed_med) as maxaed_med,
max(vitals_time) as maxvitals_time, min(vitals_time) as minvitals_time,
max(first_vitals_time) as maxfirst_vitals_time, min(first_vitals_time) as minfirst_vitals_time, 
max(last_vitals_time) as maxlast_vitals_time, min(last_vitals_time) as minlast_vitals_time, 
max(expired) as maxexpired, 
max(died01) as maxdied01, 
max(died_ever) as maxdied_ever,
max(los) as maxlos, avg(los) as avglos, 
max(icd9_477_x) as maxicd9_477_x,  
max(icd9_691_x) as maxicd9_691_x, 
max(icd9_493_x) as maxicd9_493_x, 
max(icd9_995_3) as maxicd9_995_3, 
max(icd9_558_3) as maxicd9_558_3, 
max(route) as maxroute, count(route) as countroute, 
max(sepsis_glucocorticoid) as maxsepsis_glucocorticoid,
max(sepsis_antibiotic) as maxsepsis_antibiotic,
max(encounter_masterdata) as maxencounter_masterdata,
max(infxnqsofa) as maxinfxnqsofa,
max(los_total) as maxlos_total, avg(los_total) as avglos_total, 
max(age) as maxage, 
max(temp_c) as maxtemp_c, min(temp_c) as mintemp_c, avg(temp_c) as avgtemp_c,
max(icu_flag) as maxicu_flag,
max(num_icustays) as maxnum_icustays, 
max(temp_c_ecart) as maxtemp_c_ecart, min(temp_c_ecart) as mintemp_c_ecart, avg(temp_c_ecart) as avgtemp_c_ecart,
max(potassium_ecart) as maxpotassium_ecart, avg(potassium_ecart) as avgpotassium_ecart, 
max(ecart_score) as maxecart_score, avg(ecart_score) as avgecart_score,
max(pao2_sofa) as maxpao2_sofa, sum(pao2_sofa) as sumpao2_sofa, 
max(fio2_final3_sofa) as maxfio2_final3_sofa, sum(fio2_final3_sofa) as sumfio2_final3_sofa, 
max(gcs_score_sofa) as maxgcs_score_sofa, min(gcs_score_sofa) as mingcs_score_sofa, 
max(sofa_resp) as maxsofa_resp, min(sofa_resp) as minsofa_resp, 
max(sofa_coag) as maxsofa_coag, min(sofa_coag) as minsofa_coag, 
max(sofa_bili) as maxsofa_bili, min(sofa_bili) as minsofa_bili, 
max(sofa_card) as maxsofa_card, min(sofa_card) as minsofa_card, 
max(sofa_gcs) as maxsofa_gcs, min(sofa_gcs) as minsofa_gcs, 
max(sofa_cr) as maxsofa_cr, min(sofa_cr) as minsofa_cr, 
max(sofa_score) as maxsofa_score, avg(sofa_score) as avgsofa_score, 
max(encount_enum) as maxencount_enum, avg(encount_enum) as avgencount_enum, 
max(antibiotic_ad) as maxantibiotic_ad, 
max(antiarrhythmic_ad) as maxantiarrhythmic_ad, 
max(anticoag_ad) as maxanticoag_ad, 
max(antipsych_ad) as maxantipsych_ad, 
max(avnodal_ad) as maxavnodal_ad, 
max(diuretic_ad) as maxdiuretic_ad, 
max(fungal_ad) as maxfungal_ad, 
max(hypogly_ad) as maxhypogly_ad, 
max(immuno_ad) as maximmuno_ad, 
max(steroid_ad) as maxsteroid_ad, 
max(antiviral_ad) as maxantiviral_ad, 
max(chest_xray) as sumchest_xray, 
max(chestab_w_ct) as sumchestab_w_ct, 
max(chestab_wo_ct) as sumchestab_wo_ct, 
max(headneck_w_ct) as sumheadneck_w_ct, 
max(cul_blood_ord) as maxcul_blood_ord, 
max(cul_urine_ord) as maxcul_urine_ord, 
max(cul_other_ord) as maxcul_other_ord, 
max(cul_stool_ord) as maxcul_stool_ord, 
sum(elix_comorb) as sumelix_comorb, avg(elix_comorb)as avgelix_comorb, 
max(urin_cath) as maxurin_cath, 
max(urin_output) as maxurin_output, 
max(mech_ventil) as maxmech_ventil, 
max(benzo_diaz) as maxbenzo_diaz, 
max(end_of_life) as maxend_of_life, 
max(ekg_ecg) as maxekg_ecg, sum(ekg_ecg) as sumekg_ecg, 
count(central_line) as countcentral_line, 
sum(mob_lo) as summob_lo, 
max(age_yr) as maxage_yr, 
avg(albumin_c) as avgalbumin_c, min(albumin_c) as minalbumin_c, 
avg(allphos_c) as avgallphos_c, 
avg(avpu_c) as avgavpu_c,  
avg(bun_c) as avgbun_c, 
avg(bun_cr_c) as avgbun_cr_c, 
avg(calcium_c) as avgcalcium_c, 
avg(co2_c) as avgco2_c, 
avg(creatinine_c) as avgcreatinine_c, 
avg(dbp_c) as avgdbp_c, 
avg(gluc_ser_c) as avggluc_ser_c, 
avg(hb_c) as avghb_c, 
avg(o2sat_c) as avgo2sat_c, 
avg(platelet_count_c) as avgplatelet_count_c, min(platelet_count_c) as minplatelet_count_c, 
avg(ppi_c) as avgppi_c, 
avg(rr_c) as avgrr_c, 
avg(sbp_c) as avgsbp_c, 
avg(sgot_c) as avgsgot_c, 
avg(sodium_c) as avgsodium_c, 
avg(wbc_c) as avgwbc_c, min(wbc_c) as minwbc_c
FROM sepsis_data
GROUP BY encounter_id;
"""

df = pysqldf(q)
print(df.head())
# Out:
#    patient_id  encounter_id             mintime             maxtime  loc_cat  maxIVF_meds  countIVF_meds maxIVF_volume avgIVF_volume maxIV_intake   maxfio2   avgfio2  maxfio2_vent  avgfio2_vent  maxgastric_output  mingastric_output  avggastric_output  maxgcs_eye  mingcs_eye  maxgcs_motor  mingcs_motor  maxgcs_score  avggcs_score  maxgcs_verbal  mingcs_verbal  maxhfo_fio2  avghfo_fio2  maxmap_notcalc  minmap_notcalc  avgmap_notcalc  maxmap_zzz  minmap_zzz  avgmap_zzz  maxnasal_cannula  maxni_fio2  avgni_fio2 maxni_vent maxo2_device  maxo2_flow  mino2_flow  avgo2_flow  maxrass  minrass  avgrass  maxroomair   mintemp   maxtemp  maxtube_output  avgtube_output  maxwound_output  avgwound_output  maxfio2_final  maxfio2_final2  maxsf_ratio_old  avgsf_ratio_old  maxcontam_true  maxstaph  maxabs_bands  minabs_bands  avgabs_bands  maxabs_neutrophils  maxabs_neutrophils  avgabs_neutrophils    maxalt    minalt    avgalt  maxantitrypsin  avgantitrypsin maxauto_abs_neutrophils  \
# ...

# %%
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df.sort_values(['patient_id']).head(50)
# Out:
#      patient_id  encounter_id             mintime             maxtime  loc_cat  maxIVF_meds  countIVF_meds maxIVF_volume avgIVF_volume maxIV_intake   maxfio2   avgfio2  maxfio2_vent  avgfio2_vent  maxgastric_output  mingastric_output  avggastric_output  maxgcs_eye  mingcs_eye  maxgcs_motor  mingcs_motor  maxgcs_score  avggcs_score  maxgcs_verbal  mingcs_verbal  maxhfo_fio2  avghfo_fio2  maxmap_notcalc  minmap_notcalc  avgmap_notcalc  maxmap_zzz  minmap_zzz  avgmap_zzz  maxnasal_cannula  maxni_fio2  avgni_fio2 maxni_vent maxo2_device  maxo2_flow  mino2_flow  avgo2_flow   maxrass   minrass   avgrass  maxroomair   mintemp   maxtemp  maxtube_output  avgtube_output  maxwound_output  avgwound_output  maxfio2_final  maxfio2_final2  maxsf_ratio_old  avgsf_ratio_old  maxcontam_true  maxstaph  maxabs_bands  minabs_bands  avgabs_bands  maxabs_neutrophils  maxabs_neutrophils  avgabs_neutrophils    maxalt    minalt    avgalt  maxantitrypsin  avgantitrypsin maxauto_abs_neutrophils  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Columns: 450 entries, patient_id to minwbc_c
# dtypes: float64(374), int64(17), object(59)
# memory usage: 1.4+ MB
