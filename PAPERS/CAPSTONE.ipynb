# %%
import pandas as pd

# %%
d = pd.DataFrame.from_csv('partial_datacsv.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (5,205,206,256) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
d.head(50)
# Out:
#             encounter_id                time loc_cat             unit1 unit2  \
# patient_id
# 155043            155164  25apr2013 22:36:00    WARD              T3SW   NaN
# 155043            155164  26apr2013 17:00:00    WARD  TS356 (room 117)   NaN
# 155043            155164  26apr2013 05:18:00    WARD  TS356 (room 117)   NaN
# 155043            155164  26apr2013 14:32:00    WARD               NaN   NaN
# 155043            155164  26apr2013 02:49:00    WARD               NaN   NaN
# 155043            155164  26apr2013 23:37:00    WARD               NaN   NaN
# 155043            155164  27apr2013 06:00:00    WARD  TS356 (room 117)   NaN
# 155043            155164  26apr2013 05:00:00    WARD               NaN   NaN
# 155043            155164  25apr2013 23:01:00    WARD  TS356 (room 117)   NaN
# 155043            155164  26apr2013 12:45:00    WARD  TS356 (room 117)   NaN
# 155043            155164  26apr2013 14:00:00    WARD  TS356 (room 117)   NaN
# ...

# %%
d.describe()
# Out:
#        encounter_id      IVF_meds  IVF_volume  IV_intake          avpu  \
# count  1.693470e+05  10181.000000   11.000000        0.0  13835.000000
# mean   2.408889e+06    117.301304  127.636364        NaN      0.467293
# std    1.353585e+05    513.899268  137.264178        NaN      0.721024
# min    1.551640e+05      0.000000    0.000000        NaN      0.000000
# 25%    2.310390e+06     50.000000   42.000000        NaN      0.000000
# 50%    2.358583e+06     90.000000  100.000000        NaN      0.000000
# 75%    2.530717e+06    125.000000  134.000000        NaN      1.000000
# max    2.669231e+06  51000.000000  500.000000        NaN      3.000000
#
#            avpu_old           dbp         fio2    fio2_vent  gastric_output  \
# count  12601.000000  60096.000000  8744.000000  5940.000000     1143.000000
# mean       0.462662     69.027506    54.214547    55.070202      139.354331
# std        0.697995     15.640930    20.542531    28.311403      240.651275
# ...
